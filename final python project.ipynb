# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
st = "C:\\Users\\HP\\Downloads\\bank.csv".strip("‪u+202a")

# %%
bank = pd.read_csv(st)

# %%
bank.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
bank.shape
# Out:
# (45211, 19)

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  45211 non-null  int64
#  1   age         45191 non-null  float64
#  2   salary      45211 non-null  int64
#  3   balance     45211 non-null  int64
#  4   marital     45211 non-null  object
#  5   jobedu      45211 non-null  object
#  6   targeted    45211 non-null  object
#  7   default     45211 non-null  object
#  8   housing     45211 non-null  object
#  9   loan        45211 non-null  object
#  10  contact     45211 non-null  object
#  11  day         45211 non-null  int64
#  12  month       45161 non-null  object
#  13  duration    45211 non-null  object
#  14  campaign    45211 non-null  int64
#  15  pdays       45211 non-null  int64
#  16  previous    45211 non-null  int64
#  17  poutcome    45211 non-null  object
#  18  response    45181 non-null  object
# ...

# %%
bank.isna().sum()
# Out:
# customerid     0
# age           20
# salary         0
# balance        0
# marital        0
# jobedu         0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# dtype: int64

# %%
bank["age"].fillna(bank["age"].mean(),inplace = True)

# %%
bank.isna().sum()
# Out:
# customerid     0
# age            0
# salary         0
# balance        0
# marital        0
# jobedu         0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# dtype: int64

# %%
bank=bank.dropna()

# %%
bank.isna().sum()
# Out:
# customerid    0
# age           0
# salary        0
# balance       0
# marital       0
# jobedu        0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response      0
# dtype: int64

# %%
bank.describe().T
# Out:
#               count          mean           std     min      25%      50%  \
# customerid  45131.0  22609.179212  13049.071795     1.0  11310.5  22611.0
# age         45131.0     40.938351     10.617247    18.0     33.0     39.0
# salary      45131.0  57005.982584  32091.789742     0.0  20000.0  60000.0
# balance     45131.0   1362.378853   3045.661210 -8019.0     72.0    448.0
# day         45131.0     15.808247      8.323554     1.0      8.0     16.0
# campaign    45131.0      2.762536      3.093312     1.0      1.0      2.0
# pdays       45131.0     40.209922    100.149295    -1.0     -1.0     -1.0
# previous    45131.0      0.580732      2.305134     0.0      0.0      0.0
#
#                 75%       max
# customerid  33908.5   45211.0
# age            48.0      95.0
# salary      70000.0  120000.0
# balance      1428.0  102127.0
# day            21.0      31.0
# campaign        3.0      63.0
# pdays          -1.0     871.0
# previous        0.0     275.0

# %%
cont = bank.select_dtypes(include=np.number)

# %%
cont.columns
# Out:
# Index(['customerid', 'age', 'salary', 'balance', 'day', 'campaign', 'pdays',
#        'previous'],
#       dtype='object')

# %%
for i in cont:
    plt.figure(figsize = (8,6))
    sns.boxplot(x=i,data = cont)

# %% [markdown]
# age,balance,campaign,previous,pdays are the columns having outliers

# %%
for i in cont:
    plt.figure(figsize =(6,8))
    sns.histplot(x=i,data = cont)
    plt.show()

# %% [markdown]
# age is right skewed.

# %%
bank['age'].median()
# Out:
# 39.0

# %%
bank['balance'].median()
# Out:
# 448.0

# %%
bank['campaign'].median()
# Out:
# 2.0

# %%
bank['pdays'].median()
# Out:
# -1.0

# %%
bank['marital'].value_counts()
# Out:
# married     27164
# single      12766
# divorced     5201
# Name: marital, dtype: int64

# %%
bank['jobedu'].value_counts()
# Out:
# management,tertiary        7790
# blue-collar,secondary      5366
# technician,secondary       5221
# admin.,secondary           4210
# blue-collar,primary        3750
# services,secondary         3451
# technician,tertiary        1963
# management,secondary       1120
# retired,secondary           982
# self-employed,tertiary      827
# retired,primary             793
# unemployed,secondary        728
# entrepreneur,tertiary       685
# housemaid,primary           623
# self-employed,secondary     577
# admin.,tertiary             571
# entrepreneur,secondary      542
# student,secondary           508
# blue-collar,unknown         453
# housemaid,secondary         395
# retired,tertiary            366
# services,primary            343
# management,primary          294
# unemployed,tertiary         289
# unemployed,primary          257
# technician,unknown          242
# management,unknown          241
# student,tertiary            222
# admin.,primary              209
# ...

# %%
bank.pivot_table(index=['housing','loan'],values='campaign',aggfunc = 'count')
# Out:
#               campaign
# housing loan
# no      no       17173
#         yes       2875
# yes     no       20723
#         yes       4360

# %%
bank.pivot_table(index =['targeted','default'],values ='customerid',aggfunc ='count')
# Out:
#                   customerid
# targeted default
# no       no             7975
#          yes             126
# yes      no            36341
#          yes             689

# %%
bank.pivot_table(index=['targeted','response'],values = 'campaign',aggfunc ='count')
# Out:
#                    campaign
# targeted response
# no       no            6769
#          yes           1332
# yes      no           33081
#          yes           3949

# %%
bank.pivot_table(index=['response','poutcome'],values ='campaign',aggfunc ='count')
# Out:
#                    campaign
# response poutcome
# no       failure       4276
#          other         1532
#          success        531
#          unknown      33511
# yes      failure        617
#          other          307
#          success        976
#          unknown       3381

# %%
bank['age'].value_counts()
# Out:
# 32.0    2082
# 31.0    1987
# 33.0    1970
# 34.0    1925
# 35.0    1886
#         ...
# 95.0       2
# 92.0       2
# 93.0       2
# 88.0       2
# 94.0       1
# Name: age, Length: 78, dtype: int64

# %%
sns.histplot(bank['age'])
plt.show()

# %%
sns.histplot(bank['duration'])
plt.show()

# %%
sns.kdeplot(bank['balance'])
plt.show()

# %%
bank['balance'].value_counts()
# Out:
#  0        3506
#  1         195
#  2         156
#  4         139
#  3         134
#           ...
# -832         1
#  4043        1
#  6812        1
#  10077       1
#  16353       1
# Name: balance, Length: 7164, dtype: int64

# %%
bank['campaign'].value_counts()
# Out:
# 1     17512
# 2     12487
# 3      5510
# 4      3515
# 5      1762
# 6      1289
# 7       735
# 8       539
# 9       326
# 10      265
# 11      201
# 12      154
# 13      133
# 14       92
# 15       84
# 16       79
# 17       69
# 18       51
# 20       43
# 19       43
# 21       35
# 22       23
# 25       22
# 23       22
# 24       20
# 29       16
# 28       16
# 26       12
# 31       11
# 27       10
# 32        9
# 30        8
# 33        6
# 34        5
# 36        4
# 35        4
# 43        3
# 38        3
# 37        2
# 50        2
# 41        2
# 46        1
# 58        1
# 55        1
# 63        1
# 51        1
# 39        1
# 44        1
# Name: campaign, dtype: int64

# %%
bank['poutcome'].value_counts()
# Out:
# unknown    36892
# failure     4893
# other       1839
# success     1507
# Name: poutcome, dtype: int64

# %%
bank.poutcome.value_counts()
sns.countplot(x='poutcome',hue ='marital',data = bank)
plt.show()

# %%
bank.jobedu.value_counts()
# Out:
# management,tertiary        7790
# blue-collar,secondary      5366
# technician,secondary       5221
# admin.,secondary           4210
# blue-collar,primary        3750
# services,secondary         3451
# technician,tertiary        1963
# management,secondary       1120
# retired,secondary           982
# self-employed,tertiary      827
# retired,primary             793
# unemployed,secondary        728
# entrepreneur,tertiary       685
# housemaid,primary           623
# self-employed,secondary     577
# admin.,tertiary             571
# entrepreneur,secondary      542
# student,secondary           508
# blue-collar,unknown         453
# housemaid,secondary         395
# retired,tertiary            366
# services,primary            343
# management,primary          294
# unemployed,tertiary         289
# unemployed,primary          257
# technician,unknown          242
# management,unknown          241
# student,tertiary            222
# admin.,primary              209
# ...

# %%
sns.barplot(x='poutcome',y='campaign',data =bank)
plt.show()

# %%
sns.barplot(x='poutcome',y='age',data =bank)
plt.show()

# %%
bank.month.value_counts()
# Out:
# may, 2017    13738
# jul, 2017     6886
# aug, 2017     6235
# jun, 2017     5329
# nov, 2017     3963
# apr, 2017     2929
# feb, 2017     2645
# jan, 2017     1402
# oct, 2017      738
# sep, 2017      576
# mar, 2017      476
# dec, 2017      214
# Name: month, dtype: int64

# %%
bank.month.value_counts()
sns.countplot(x='poutcome',hue ='month',data =bank)
plt.show()

# %%
bank.contact.value_counts()
sns.countplot(x='response',hue ='contact',data =bank)
plt.show()

# %%
bank.targeted.value_counts()
sns.countplot(x='targeted',hue='poutcome',data= bank)
plt.show()

# %%
plt.figure(figsize =(15,7))
sns.heatmap(bank.corr(),annot= True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21460\4020423307.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(bank.corr(),annot= True)
# <Axes: >

# %%
from sklearn.preprocessing import MinMaxScaler
scale= MinMaxScaler()
cont= scale.fit_transform(cont)
cont= pd.DataFrame(cont)
cont.describe().T
# Out:
#      count      mean       std  min       25%       50%       75%  max
# 0  45131.0  0.500070  0.288632  0.0  0.250155  0.500111  0.750000  1.0
# 1  45131.0  0.297901  0.137886  0.0  0.194805  0.272727  0.389610  1.0
# 2  45131.0  0.475050  0.267432  0.0  0.166667  0.500000  0.583333  1.0
# 3  45131.0  0.085172  0.027651  0.0  0.073457  0.076871  0.085768  1.0
# 4  45131.0  0.493608  0.277452  0.0  0.233333  0.500000  0.666667  1.0
# 5  45131.0  0.028428  0.049892  0.0  0.000000  0.016129  0.032258  1.0
# 6  45131.0  0.047259  0.114850  0.0  0.000000  0.000000  0.000000  1.0
# 7  45131.0  0.002112  0.008382  0.0  0.000000  0.000000  0.000000  1.0

# %%
bank.describe().T
# Out:
#               count          mean           std     min      25%      50%  \
# customerid  45131.0  22609.179212  13049.071795     1.0  11310.5  22611.0
# age         45131.0     40.938351     10.617247    18.0     33.0     39.0
# salary      45131.0  57005.982584  32091.789742     0.0  20000.0  60000.0
# balance     45131.0   1362.378853   3045.661210 -8019.0     72.0    448.0
# day         45131.0     15.808247      8.323554     1.0      8.0     16.0
# campaign    45131.0      2.762536      3.093312     1.0      1.0      2.0
# pdays       45131.0     40.209922    100.149295    -1.0     -1.0     -1.0
# previous    45131.0      0.580732      2.305134     0.0      0.0      0.0
#
#                 75%       max
# customerid  33908.5   45211.0
# age            48.0      95.0
# salary      70000.0  120000.0
# balance      1428.0  102127.0
# day            21.0      31.0
# campaign        3.0      63.0
# pdays          -1.0     871.0
# previous        0.0     275.0

# %%
Min =1-(1.5*62)
Max =63+(1.5*62)

# %%
print(Min," ",Max)
# Out:
# -92.0   156.0

# %%
ul =bank['campaign'].mean()+(3*bank['campaign'].std())

# %%
ul
# Out:
# 12.042473011230504

# %%
ll =bank['campaign'].mean()-(3*bank['campaign'].std())

# %%
ll
# Out:
# -6.517401552587886

# %% [markdown]
# age

# %%
Min =18-(1.5*77)
Max =95+(1.5*77)

# %%
print(Min," ",Max)
# Out:
# -97.5   210.5

# %%
ul =bank['age'].mean()+(3*bank['age'].std())

# %%
ul
# Out:
# 72.79009237558489

# %%
ll =bank['age'].mean()-(3*bank['age'].std())

# %%
ll
# Out:
# 9.086609360165653

# %%
obj = bank.select_dtypes(include='object')

# %%
obj
# Out:
#         marital                  jobedu targeted default housing loan  \
# 0       married     management,tertiary      yes      no     yes   no
# 1        single    technician,secondary      yes      no     yes   no
# 2       married  entrepreneur,secondary      yes      no     yes  yes
# 3       married     blue-collar,unknown       no      no     yes   no
# 4        single         unknown,unknown       no      no      no   no
# ...         ...                     ...      ...     ...     ...  ...
# 45206   married     technician,tertiary      yes      no      no   no
# 45207  divorced         retired,primary      yes      no      no   no
# 45208   married       retired,secondary      yes      no      no   no
# 45209   married   blue-collar,secondary      yes      no      no   no
# 45210   married  entrepreneur,secondary      yes      no      no   no
#
#          contact      month              duration poutcome response
# ...

# %%
def condition(salary):
    if salary<=20000:
        return'Minimum'
    elif 20000<=salary<=50000:
        return'Average'
    elif 50000<=salary<=100000:
        return'Maximum'
    else:
        return 'NA'

# %%
bank['salary_catg']=bank['salary'].apply(condition)

# %%
bank.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response salary_catg
# ...

# %%
bank['salary_catg'].value_counts()
# Out:
# Maximum    25005
# Minimum    13481
# Average     5160
# NA          1485
# Name: salary_catg, dtype: int64

# %%
bank.groupby(['salary_catg','response']).campaign.mean().plot(kind='bar')
# Out:
# <Axes: xlabel='salary_catg,response'>
